# %% [markdown]
# # Write Meta docs to Markdown
#
# Quick scripts to write the MongoDB meta documentation to Markdown

# %%
# !pip install python-frontmatter
# Out:
# Requirement already satisfied: python-frontmatter in /Users/ben.p/.pyenv/versions/3.10.5/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: PyYAML in /Users/ben.p/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from python-frontmatter) (6.0.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import json
import os
from datetime import datetime
import frontmatter
import shutil

# Read pages file from JSON string to list of dicts
pages_file = "meta.pages.json"
with open(pages_file, 'r') as f:
    pages = json.load(f)

# Directory to save markdown files
output_dir = "md_docs"
if os.path.exists(output_dir):
    # Remove the directory and all its contents
    print(f"Removed output dir '{output_dir}' and its contents")
    shutil.rmtree(output_dir)

os.makedirs(output_dir, exist_ok=True)

# Parse each dict and format as frontmatter
for page in pages:
    frontmatter_dict = {
        'title': page['title'].strip(),
        'url': page['url'],
        'updated': page['updated']['$date']
    }
    content = page['body']
    
    # Create frontmatter object
    post = frontmatter.Post(content, **frontmatter_dict)
    
    # Convert post to string with frontmatter
    page_str = frontmatter.dumps(post)
    
    # Create a file path based on the URL
    uri = page['url'].replace('https://mongodb.com/docs/meta/', '')

    if uri.endswith('/'):
        # Remove the last '/'
        uri = uri[:-1]
        
    print(uri)
    file_path = os.path.join(
        output_dir,
        *uri.split('/')) + ".md"
    if(file_path == ".md"):
        file_path = "index.md"
    print(file_path)
    
    # Ensure the directory structure exists
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Write each page string to a file in the appropriate subdirectory
    with open(file_path, 'w') as f:
        f.write(page_str)
# Out:
# Removed output dir 'md_docs' and its contents
# error-kb
# md_docs/error-kb.md
# organization
# md_docs/organization.md
# practices
# md_docs/practices.md
# redirects
# md_docs/redirects.md
# reference
# md_docs/reference.md
#
# md_docs/.md
# images-guide
# md_docs/images-guide.md
# reference/cond
# md_docs/reference/cond.md
# reference/eval
# md_docs/reference/eval.md
# reference/lightbox
# md_docs/reference/lightbox.md
# reference/options
# md_docs/reference/options.md
# reference/source-constants
# md_docs/reference/source-constants.md
# reference/suppressing-prevnext-links
# md_docs/reference/suppressing-prevnext-links.md
# reference/xmlrole
# md_docs/reference/xmlrole.md
# snooty
# md_docs/snooty.md
# style-guide
# md_docs/style-guide.md
# reference/icon
# md_docs/reference/icon.md
# style-guide/control-panels-and-portals
# md_docs/style-guide/control-panels-and-portals.md
# reference/apiargs
# md_docs/reference/apiargs.md
# style-guide/information-types/index
# md_docs/style-guide/information-types/index.md
# reference/code-blocks
# md_docs/reference/code-blocks.md
# style-guide/information-types/prototypes/concept
# md_docs/style-guide/information-types/prototypes/concept.md
# style-guide/information-types/prototypes/reference
# md_docs/style-guide/information-types/prototypes/reference.md
# style-guide/information-types/prototypes/task
# md_docs/style-guide/information-types/prototypes/task.md
# style-guide/markup-guidelines
# md_docs/style-guide/markup-guidelines.md
# style-guide/markup/directives
# md_docs/style-guide/markup/directives.md
# style-guide/markup/directives/metadata
# md_docs/style-guide/markup/directives/metadata.md
# style-guide/markup/directives/sharedinclude
# md_docs/style-guide/markup/directives/sharedinclude.md
# style-guide/markup/directives/tables
# md_docs/style-guide/markup/directives/tables.md
# style-guide/markup/directives/tabs
# md_docs/style-guide/markup/directives/tabs.md
# style-guide/markup/format/roles
# md_docs/style-guide/markup/format/roles.md
# style-guide/markup/format/lists
# md_docs/style-guide/markup/format/lists.md
# style-guide/markup/format/substitutions
# md_docs/style-guide/markup/format/substitutions.md
# style-guide/markup/headings
# md_docs/style-guide/markup/headings.md
# style-guide/markup/inline
# md_docs/style-guide/markup/inline.md
# style-guide/quickstart
# md_docs/style-guide/quickstart.md
# style-guide/revision-history
# md_docs/style-guide/revision-history.md
# style-guide/screenshots/diagram-guidelines
# md_docs/style-guide/screenshots/diagram-guidelines.md
# style-guide/release-notes-guidelines
# md_docs/style-guide/release-notes-guidelines.md
# style-guide/screenshots/index
# md_docs/style-guide/screenshots/index.md
# style-guide/screenshots/screenshot-guidelines
# md_docs/style-guide/screenshots/screenshot-guidelines.md
# style-guide/seo-guidelines
# md_docs/style-guide/seo-guidelines.md
# style-guide/style/abbreviations
# md_docs/style-guide/style/abbreviations.md
# style-guide/style/capitalization
# md_docs/style-guide/style/capitalization.md
# style-guide/style/citations
# md_docs/style-guide/style/citations.md
# style-guide/error-message-guidelines
# md_docs/style-guide/error-message-guidelines.md
# style-guide/style/code-examples
# md_docs/style-guide/style/code-examples.md
# style-guide/style/contractions
# md_docs/style-guide/style/contractions.md
# style-guide/style/callouts
# md_docs/style-guide/style/callouts.md
# style-guide/information-types/prototypes
# md_docs/style-guide/information-types/prototypes.md
# style-guide/style/email-addresses
# md_docs/style-guide/style/email-addresses.md
# style-guide/style/dates
# md_docs/style-guide/style/dates.md
# style-guide/style/file-types
# md_docs/style-guide/style/file-types.md
# style-guide/style/index
# md_docs/style-guide/style/index.md
# style-guide/style/ip-addresses
# md_docs/style-guide/style/ip-addresses.md
# style-guide/style/keyboard-keys
# md_docs/style-guide/style/keyboard-keys.md
# style-guide/style/links-and-cross-references
# md_docs/style-guide/style/links-and-cross-references.md
# style-guide/style/lists
# md_docs/style-guide/style/lists.md
# style-guide/style/glossaries
# md_docs/style-guide/style/glossaries.md
# style-guide/style/messages
# md_docs/style-guide/style/messages.md
# style-guide/style/names
# md_docs/style-guide/style/names.md
# style-guide/style/numbers
# md_docs/style-guide/style/numbers.md
# style-guide/style/parameters
# md_docs/style-guide/style/parameters.md
# style-guide/style/placeholder-variable-text
# md_docs/style-guide/style/placeholder-variable-text.md
# style-guide/style/prepositions
# md_docs/style-guide/style/prepositions.md
# style-guide/style/product-names-version-numbers
# md_docs/style-guide/style/product-names-version-numbers.md
# style-guide/style/punctuation
# md_docs/style-guide/style/punctuation.md
# style-guide/style/plurals
# md_docs/style-guide/style/plurals.md
# style-guide/style/symbols
# md_docs/style-guide/style/symbols.md
# style-guide/style/tables
# md_docs/style-guide/style/tables.md
# style-guide/style/tasks
# md_docs/style-guide/style/tasks.md
# style-guide/style/telephone-numbers
# md_docs/style-guide/style/telephone-numbers.md
# style-guide/style/text-formatting
# md_docs/style-guide/style/text-formatting.md
# style-guide/style/time
# md_docs/style-guide/style/time.md
# style-guide/style/titles-and-headings
# md_docs/style-guide/style/titles-and-headings.md
# style-guide/style/toc-labels
# md_docs/style-guide/style/toc-labels.md
# style-guide/style/urls
# md_docs/style-guide/style/urls.md
# style-guide/style/version
# md_docs/style-guide/style/version.md
# style-guide/style/voice-and-tone
# md_docs/style-guide/style/voice-and-tone.md
# style-guide/terminology/concise-terms
# md_docs/style-guide/terminology/concise-terms.md
# style-guide/terminology/general-term-guidelines/avoid-obscure-words
# md_docs/style-guide/terminology/general-term-guidelines/avoid-obscure-words.md
# style-guide/style/cloud-account-info
# md_docs/style-guide/style/cloud-account-info.md
# style-guide/terminology/general-term-guidelines/use-consistent-terms
# md_docs/style-guide/terminology/general-term-guidelines/use-consistent-terms.md
# style-guide/terminology/index
# md_docs/style-guide/terminology/index.md
# style-guide/terminology/general-term-guidelines/use-consistent-time-references
# md_docs/style-guide/terminology/general-term-guidelines/use-consistent-time-references.md
# style-guide/terminology/general-term-guidelines/use-short-words
# md_docs/style-guide/terminology/general-term-guidelines/use-short-words.md
# style-guide/style/copyrights
# md_docs/style-guide/style/copyrights.md
# style-guide/terminology/alphabetical-terms
# md_docs/style-guide/terminology/alphabetical-terms.md
# style-guide/user-interface-guidelines
# md_docs/style-guide/user-interface-guidelines.md
# style-guide/writing/clarify-gerunds-participles
# md_docs/style-guide/writing/clarify-gerunds-participles.md
# style-guide/writing/clarify-modifiers
# md_docs/style-guide/writing/clarify-modifiers.md
# style-guide/writing/use-active-voice
# md_docs/style-guide/writing/use-active-voice.md
# style-guide/writing/use-correct-punctuation
# md_docs/style-guide/writing/use-correct-punctuation.md
# style-guide/writing/index
# md_docs/style-guide/writing/index.md
# style-guide/writing/use-gender-neutral-pronouns
# md_docs/style-guide/writing/use-gender-neutral-pronouns.md
# style-guide/writing/use-effective-verbs
# md_docs/style-guide/writing/use-effective-verbs.md
# style-guide/writing/use-interjections-with-care
# md_docs/style-guide/writing/use-interjections-with-care.md
# style-guide/writing/use-positive-statements
# md_docs/style-guide/writing/use-positive-statements.md
# style-guide/writing/use-present-tense
# md_docs/style-guide/writing/use-present-tense.md
# style-guide/writing/use-pronouns-carefully
# md_docs/style-guide/writing/use-pronouns-carefully.md
# style-guide/writing/use-that-which-correctly
# md_docs/style-guide/writing/use-that-which-correctly.md
# style-guide/writing/write-clear-concise-sentences-paragraphs
# md_docs/style-guide/writing/write-clear-concise-sentences-paragraphs.md
# style-guide/writing/write-for-accessibility
# md_docs/style-guide/writing/write-for-accessibility.md
# style-guide/writing/write-to-the-user
# md_docs/style-guide/writing/write-to-the-user.md
# translation
# md_docs/translation.md
# tutorials
# md_docs/tutorials.md
# tutorials/guide
# md_docs/tutorials/guide.md
# tutorials/install
# md_docs/tutorials/install.md
# tutorials/repo
# md_docs/tutorials/repo.md
# tutorials/generating-a-browser-list
# md_docs/tutorials/generating-a-browser-list.md
# tutorials/version-bumping
# md_docs/tutorials/version-bumping.md
# style-guide/terminology/general-term-guidelines/index
# md_docs/style-guide/terminology/general-term-guidelines/index.md
# style-guide/terminology/terms-for-global-audience
# md_docs/style-guide/terminology/terms-for-global-audience.md
